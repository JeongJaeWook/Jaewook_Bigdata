# %% [markdown]
# # 데이터 불러오기 및 탐색

# %%
import numpy as np
import pandas as pd
import string

#전처리 및 데이터 split
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('data/traindata_google_appstore.xlsm',usecols='B,C')
df_test = pd.read_excel('data/testdata_google_2011_11.xlsm',usecols='B,C')

# %%
df.columns = ['label','C1'] #열 이름 변경
print("\n[5줄만 보기]")
print("label 1 : 불량  | 0 : 정상 | 3 : 모름,기억안남,없음")
display(df.head(5))

print("\n[데이터 속성]")
print(df.info())

print("\n[데이터 label 갯수]")
print(df['label'].value_counts())
#학습할 불량샘플이 너무 작은게 아닐까..?
# Out:
# [5줄만 보기]
# label 1 : 불량  | 0 : 정상 | 3 : 모름,기억안남,없음
#    label        C1
# 0      1      ㅣㅣㅣㅣ
# 1      1  ㅠㅡㄹ레이스토어
# 2      1     ㅜ글스토어
# 3      1       ㅓㅄ음
# 4      0   히어로 스카이
# [데이터 속성]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47581 entries, 0 to 47580
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   47581 non-null  int64
#  1   C1      47581 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 743.6+ KB
# None
#
# [데이터 label 갯수]
# 0    45908
# 3     1202
# 1      471
# Name: label, dtype: int64

# %% [markdown]
# # 전처리
# 클리닝 -> 함수화
#
# **모름, 기억나지않음 등과 같은 경우는 어떤 경우엔 정상 샘플로 넘기기 때문에 label을 3으로 표시**

# %%
#클리닝 함수
def cleanText(text):
    repl =''
       
    if text.isdecimal() : #숫자로만 구성되어 있을 때 공백 치환
        text = ''
    
    text = text.lower() #영어일경우 소문자로 변경
    text = text.strip().replace('\\','')# 기호 치환
    
    pattern = '([ㄱ-ㅎㅏ-ㅣ]+)' # 자음, 모음 제거
    text = re.sub(pattern= pattern, repl=repl, string=text)
          
    pattern = '[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]' # 특수기호 제거
    text = re.sub(pattern= pattern, repl=repl, string=text)
    
    if len(text)==0 :
        text = '불량'
    #text = text.replace(' ','불량')# 모든 공백 제거 이건 아닌것 같아서 삭제
    
    return text

# %%
# 인자로 입력받은 DataFrame을 복사 한 뒤 C1 컬럼 문자형 변환하고 복사된 DataFrame 반환
def get_preprocessed_df(df=None):
    df_copy = df.copy()
    df_copy.columns = ['label','C1'] #열 이름 변경
           
    #1. 응답에 숫자도 있어서 int 형으로 처리됌 -> 문자형으로 변환
    df_text = df_copy['C1'].apply(str)   
       
    #2. 텍스트 클리닝 (자음/모음/숫자만으로 이루어진 경우 빈칸처리, 특수기호 제거)
    df_text = df_text.map(lambda x: cleanText(x))
    
    #3.. 더 있나?
        
    #마지막에 다시 대입
    df_copy['C1'] = df_text
    
    return df_copy

# %%
df_copy = get_preprocessed_df(df)
df_test = get_preprocessed_df(df_test)
# df_copy.isnull().sum() #공백은 불량으로 처리..?

# %% [markdown]
# # 임베딩
# -단어 수준 임베딩
#
#     Latent Semantic Analysis
#     Word2Vec
#     GloVe
#     FastText
#     Swivel
#
# -문장 수준 임베딩
#
#     Weighted Embeddings
#     Latent Semantic Analysis
#     Latent Dirichlet Allocation
#     Doc2Vec
#     Embeddings from Language Models (ELMo)
#     Bidirectional Encoder Representations from Transformer (BERT)
#
#
# 출처 : https://github.com/ratsgo/embedding

# %%
#벡터화

# vectorizer = TfidfVectorizer()
# X_features = vectorizer.fit_transform(df_copy['C1'].copy())
# df_copy['X_features'] = X_features
# y_target = df_copy['label'].copy()
# df_copy

# %%
#벡터화
vectorizer = TfidfVectorizer()
def vectorize_tfid_fit(df_copy):
    
    
    X_features = vectorizer.fit_transform(df_copy['C1'].copy())
    df_copy['X_features'] = X_features
    y_target = df_copy['label'].copy()
    return X_features , y_target

def vectorize_tfid_unfit(df_copy):
    
    
    X_features = vectorizer.transform(df_copy['C1'].copy())
    df_copy['X_features'] = X_features
    y_target = df_copy['label'].copy()
    return X_features , y_target

# %% [markdown]
# # 데이터 나누기

# %%
#전체 데이터를 테스트로
#X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=333,stratify=y_target )

# %%
X_train,y_train =  vectorize_tfid_fit(df_copy)
X_test,y_test =  vectorize_tfid_unfit(df_test)

# %%
# LightGBM의 파이썬 패키지인 lightgbm에서 LGBMClassifier 임포트
from lightgbm import LGBMClassifier

# 앞서 XGBoost와 동일하게 n_estimators는 400 설정. 
lgbm_wrapper = LGBMClassifier(n_estimators=400)

# LightGBM도 XGBoost와 동일하게 조기 중단 수행 가능. 
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=400, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [1]	valid_0's multi_logloss: 0.0996645
# Training until validation scores don't improve for 400 rounds
# [2]	valid_0's multi_logloss: 0.0928569
# [3]	valid_0's multi_logloss: 0.0876338
# [4]	valid_0's multi_logloss: 0.083392
# [5]	valid_0's multi_logloss: 0.0799235
# [6]	valid_0's multi_logloss: 0.0770033
# [7]	valid_0's multi_logloss: 0.0745322
# [8]	valid_0's multi_logloss: 0.072363
# [9]	valid_0's multi_logloss: 0.0705533
# [10]	valid_0's multi_logloss: 0.0689015
# [11]	valid_0's multi_logloss: 0.0675188
# [12]	valid_0's multi_logloss: 0.0662681
# [13]	valid_0's multi_logloss: 0.0651776
# [14]	valid_0's multi_logloss: 0.0642276
# [15]	valid_0's multi_logloss: 0.0633455
# [16]	valid_0's multi_logloss: 0.0625992
# [17]	valid_0's multi_logloss: 0.061965
# [18]	valid_0's multi_logloss: 0.0613868
# [19]	valid_0's multi_logloss: 0.0608495
# [20]	valid_0's multi_logloss: 0.0604197
# [21]	valid_0's multi_logloss: 0.0599518
# [22]	valid_0's multi_logloss: 0.0596118
# [23]	valid_0's multi_logloss: 0.0592889
# [24]	valid_0's multi_logloss: 0.058999
# [25]	valid_0's multi_logloss: 0.0586923
# [26]	valid_0's multi_logloss: 0.0584614
# [27]	valid_0's multi_logloss: 0.0582151
# [28]	valid_0's multi_logloss: 0.0579988
# [29]	valid_0's multi_logloss: 0.0578527
# [30]	valid_0's multi_logloss: 0.057642
# [31]	valid_0's multi_logloss: 0.0575383
# [32]	valid_0's multi_logloss: 0.0573777
# [33]	valid_0's multi_logloss: 0.0572458
# [34]	valid_0's multi_logloss: 0.0571706
# [35]	valid_0's multi_logloss: 0.0570434
# [36]	valid_0's multi_logloss: 0.0569628
# [37]	valid_0's multi_logloss: 0.0568931
# [38]	valid_0's multi_logloss: 0.0567804
# [39]	valid_0's multi_logloss: 0.0566831
# [40]	valid_0's multi_logloss: 0.0566742
# [41]	valid_0's multi_logloss: 0.056533
# [42]	valid_0's multi_logloss: 0.0564504
# [43]	valid_0's multi_logloss: 0.0563871
# [44]	valid_0's multi_logloss: 0.0563559
# [45]	valid_0's multi_logloss: 0.0562963
# [46]	valid_0's multi_logloss: 0.0562985
# [47]	valid_0's multi_logloss: 0.0562111
# [48]	valid_0's multi_logloss: 0.0562442
# [49]	valid_0's multi_logloss: 0.0561819
# [50]	valid_0's multi_logloss: 0.0562565
# [51]	valid_0's multi_logloss: 0.0562169
# [52]	valid_0's multi_logloss: 0.056228
# [53]	valid_0's multi_logloss: 0.0562231
# [54]	valid_0's multi_logloss: 0.0561888
# [55]	valid_0's multi_logloss: 0.0562715
# [56]	valid_0's multi_logloss: 0.0562373
# [57]	valid_0's multi_logloss: 0.0563008
# [58]	valid_0's multi_logloss: 0.0562986
# [59]	valid_0's multi_logloss: 0.0563541
# [60]	valid_0's multi_logloss: 0.0563472
# [61]	valid_0's multi_logloss: 0.0564085
# [62]	valid_0's multi_logloss: 0.0563945
# [63]	valid_0's multi_logloss: 0.056492
# [64]	valid_0's multi_logloss: 0.0564908
# [65]	valid_0's multi_logloss: 0.0565302
# [66]	valid_0's multi_logloss: 0.0566343
# [67]	valid_0's multi_logloss: 0.056604
# [68]	valid_0's multi_logloss: 0.0567029
# [69]	valid_0's multi_logloss: 0.0567105
# [70]	valid_0's multi_logloss: 0.0567611
# [71]	valid_0's multi_logloss: 0.056777
# [72]	valid_0's multi_logloss: 0.0568663
# [73]	valid_0's multi_logloss: 0.0568414
# [74]	valid_0's multi_logloss: 0.056938
# [75]	valid_0's multi_logloss: 0.0569203
# [76]	valid_0's multi_logloss: 0.0570131
# [77]	valid_0's multi_logloss: 0.0570752
# [78]	valid_0's multi_logloss: 0.0571178
# [79]	valid_0's multi_logloss: 0.0571948
# [80]	valid_0's multi_logloss: 0.0572376
# [81]	valid_0's multi_logloss: 0.057226
# [82]	valid_0's multi_logloss: 0.0573273
# [83]	valid_0's multi_logloss: 0.0573177
# [84]	valid_0's multi_logloss: 0.0574125
# [85]	valid_0's multi_logloss: 0.0574034
# [86]	valid_0's multi_logloss: 0.057485
# [87]	valid_0's multi_logloss: 0.0575068
# [88]	valid_0's multi_logloss: 0.0575802
# [89]	valid_0's multi_logloss: 0.0576029
# [90]	valid_0's multi_logloss: 0.0576569
# [91]	valid_0's multi_logloss: 0.0576549
# [92]	valid_0's multi_logloss: 0.0577541
# [93]	valid_0's multi_logloss: 0.0577568
# [94]	valid_0's multi_logloss: 0.0577817
# [95]	valid_0's multi_logloss: 0.0578522
# [96]	valid_0's multi_logloss: 0.0578871
# [97]	valid_0's multi_logloss: 0.0578937
# [98]	valid_0's multi_logloss: 0.0579008
# [99]	valid_0's multi_logloss: 0.0579668
# [100]	valid_0's multi_logloss: 0.0579798
# [101]	valid_0's multi_logloss: 0.0580157
# [102]	valid_0's multi_logloss: 0.0580208
# [103]	valid_0's multi_logloss: 0.0580272
# [104]	valid_0's multi_logloss: 0.0580335
# [105]	valid_0's multi_logloss: 0.0580988
# [106]	valid_0's multi_logloss: 0.0581112
# [107]	valid_0's multi_logloss: 0.0581171
# [108]	valid_0's multi_logloss: 0.0581217
# [109]	valid_0's multi_logloss: 0.0581268
# [110]	valid_0's multi_logloss: 0.0581323
# [111]	valid_0's multi_logloss: 0.0581377
# [112]	valid_0's multi_logloss: 0.058149
# [113]	valid_0's multi_logloss: 0.0581545
# [114]	valid_0's multi_logloss: 0.0581893
# [115]	valid_0's multi_logloss: 0.0581944
# [116]	valid_0's multi_logloss: 0.0581993
# [117]	valid_0's multi_logloss: 0.0582041
# [118]	valid_0's multi_logloss: 0.0582089
# [119]	valid_0's multi_logloss: 0.0582136
# [120]	valid_0's multi_logloss: 0.0582182
# [121]	valid_0's multi_logloss: 0.0582228
# [122]	valid_0's multi_logloss: 0.0582273
# [123]	valid_0's multi_logloss: 0.0582318
# [124]	valid_0's multi_logloss: 0.0582362
# [125]	valid_0's multi_logloss: 0.0582402
# [126]	valid_0's multi_logloss: 0.0582445
# [127]	valid_0's multi_logloss: 0.0582489
# [128]	valid_0's multi_logloss: 0.0582531
# [129]	valid_0's multi_logloss: 0.0582573
# [130]	valid_0's multi_logloss: 0.0582615
# [131]	valid_0's multi_logloss: 0.0582656
# [132]	valid_0's multi_logloss: 0.0582696
# [133]	valid_0's multi_logloss: 0.0582736
# [134]	valid_0's multi_logloss: 0.0582777
# [135]	valid_0's multi_logloss: 0.0582817
# [136]	valid_0's multi_logloss: 0.0582856
# [137]	valid_0's multi_logloss: 0.0582895
# [138]	valid_0's multi_logloss: 0.0582933
# [139]	valid_0's multi_logloss: 0.0582971
# [140]	valid_0's multi_logloss: 0.0583009
# [141]	valid_0's multi_logloss: 0.0583047
# [142]	valid_0's multi_logloss: 0.0583084
# [143]	valid_0's multi_logloss: 0.0583121
# [144]	valid_0's multi_logloss: 0.0583158
# [145]	valid_0's multi_logloss: 0.0583194
# [146]	valid_0's multi_logloss: 0.058323
# [147]	valid_0's multi_logloss: 0.0583266
# [148]	valid_0's multi_logloss: 0.0583302
# [149]	valid_0's multi_logloss: 0.0583337
# [150]	valid_0's multi_logloss: 0.0583372
# [151]	valid_0's multi_logloss: 0.0583407
# [152]	valid_0's multi_logloss: 0.0583441
# [153]	valid_0's multi_logloss: 0.0583476
# [154]	valid_0's multi_logloss: 0.058351
# [155]	valid_0's multi_logloss: 0.0583544
# [156]	valid_0's multi_logloss: 0.0583577
# [157]	valid_0's multi_logloss: 0.058361
# [158]	valid_0's multi_logloss: 0.0583643
# [159]	valid_0's multi_logloss: 0.0583676
# [160]	valid_0's multi_logloss: 0.0583709
# [161]	valid_0's multi_logloss: 0.0583741
# [162]	valid_0's multi_logloss: 0.0583773
# [163]	valid_0's multi_logloss: 0.0583805
# [164]	valid_0's multi_logloss: 0.0583837
# [165]	valid_0's multi_logloss: 0.0583869
# [166]	valid_0's multi_logloss: 0.05839
# [167]	valid_0's multi_logloss: 0.0583931
# [168]	valid_0's multi_logloss: 0.0583962
# [169]	valid_0's multi_logloss: 0.0584053
# [170]	valid_0's multi_logloss: 0.0584084
# [171]	valid_0's multi_logloss: 0.0584114
# [172]	valid_0's multi_logloss: 0.0584144
# [173]	valid_0's multi_logloss: 0.0584175
# [174]	valid_0's multi_logloss: 0.0584205
# [175]	valid_0's multi_logloss: 0.0584234
# [176]	valid_0's multi_logloss: 0.0584264
# [177]	valid_0's multi_logloss: 0.0584293
# [178]	valid_0's multi_logloss: 0.0584323
# [179]	valid_0's multi_logloss: 0.0584352
# [180]	valid_0's multi_logloss: 0.058438
# [181]	valid_0's multi_logloss: 0.0584409
# [182]	valid_0's multi_logloss: 0.0584437
# [183]	valid_0's multi_logloss: 0.0584466
# [184]	valid_0's multi_logloss: 0.0584494
# [185]	valid_0's multi_logloss: 0.0584522
# [186]	valid_0's multi_logloss: 0.058455
# [187]	valid_0's multi_logloss: 0.0584577
# [188]	valid_0's multi_logloss: 0.0584605
# [189]	valid_0's multi_logloss: 0.0584632
# [190]	valid_0's multi_logloss: 0.0584659
# [191]	valid_0's multi_logloss: 0.0584686
# [192]	valid_0's multi_logloss: 0.0584713
# [193]	valid_0's multi_logloss: 0.058474
# [194]	valid_0's multi_logloss: 0.0584766
# [195]	valid_0's multi_logloss: 0.0584793
# [196]	valid_0's multi_logloss: 0.0584819
# [197]	valid_0's multi_logloss: 0.0584845
# [198]	valid_0's multi_logloss: 0.0584871
# [199]	valid_0's multi_logloss: 0.0584897
# [200]	valid_0's multi_logloss: 0.0584922
# [201]	valid_0's multi_logloss: 0.0584948
# [202]	valid_0's multi_logloss: 0.0584973
# [203]	valid_0's multi_logloss: 0.0584998
# [204]	valid_0's multi_logloss: 0.0585023
# [205]	valid_0's multi_logloss: 0.0585048
# [206]	valid_0's multi_logloss: 0.0585073
# [207]	valid_0's multi_logloss: 0.0585098
# [208]	valid_0's multi_logloss: 0.0585122
# [209]	valid_0's multi_logloss: 0.0585147
# [210]	valid_0's multi_logloss: 0.0585171
# [211]	valid_0's multi_logloss: 0.0585195
# [212]	valid_0's multi_logloss: 0.0585219
# [213]	valid_0's multi_logloss: 0.0585243
# [214]	valid_0's multi_logloss: 0.0585267
# [215]	valid_0's multi_logloss: 0.058529
# [216]	valid_0's multi_logloss: 0.0585314
# [217]	valid_0's multi_logloss: 0.0585337
# [218]	valid_0's multi_logloss: 0.058536
# [219]	valid_0's multi_logloss: 0.0585383
# [220]	valid_0's multi_logloss: 0.0585406
# [221]	valid_0's multi_logloss: 0.0585429
# [222]	valid_0's multi_logloss: 0.0585452
# [223]	valid_0's multi_logloss: 0.0585475
# [224]	valid_0's multi_logloss: 0.0585497
# [225]	valid_0's multi_logloss: 0.0585519
# [226]	valid_0's multi_logloss: 0.0585542
# [227]	valid_0's multi_logloss: 0.0585564
# [228]	valid_0's multi_logloss: 0.0585586
# [229]	valid_0's multi_logloss: 0.0585608
# [230]	valid_0's multi_logloss: 0.0585629
# [231]	valid_0's multi_logloss: 0.0585651
# [232]	valid_0's multi_logloss: 0.0585673
# [233]	valid_0's multi_logloss: 0.0585694
# [234]	valid_0's multi_logloss: 0.0585716
# [235]	valid_0's multi_logloss: 0.0585737
# [236]	valid_0's multi_logloss: 0.0585758
# [237]	valid_0's multi_logloss: 0.0585779
# [238]	valid_0's multi_logloss: 0.05858
# [239]	valid_0's multi_logloss: 0.0585821
# [240]	valid_0's multi_logloss: 0.0585842
# [241]	valid_0's multi_logloss: 0.0585862
# [242]	valid_0's multi_logloss: 0.0585883
# [243]	valid_0's multi_logloss: 0.0585903
# [244]	valid_0's multi_logloss: 0.0585924
# [245]	valid_0's multi_logloss: 0.0585944
# [246]	valid_0's multi_logloss: 0.0585964
# [247]	valid_0's multi_logloss: 0.0585984
# [248]	valid_0's multi_logloss: 0.0586004
# [249]	valid_0's multi_logloss: 0.0586024
# [250]	valid_0's multi_logloss: 0.0586044
# [251]	valid_0's multi_logloss: 0.0586064
# [252]	valid_0's multi_logloss: 0.0586083
# [253]	valid_0's multi_logloss: 0.0586103
# [254]	valid_0's multi_logloss: 0.0586122
# [255]	valid_0's multi_logloss: 0.0586141
# [256]	valid_0's multi_logloss: 0.0586161
# [257]	valid_0's multi_logloss: 0.058618
# [258]	valid_0's multi_logloss: 0.0586199
# [259]	valid_0's multi_logloss: 0.0586218
# [260]	valid_0's multi_logloss: 0.0586237
# [261]	valid_0's multi_logloss: 0.0586255
# [262]	valid_0's multi_logloss: 0.0586274
# [263]	valid_0's multi_logloss: 0.0586293
# [264]	valid_0's multi_logloss: 0.0586311
# [265]	valid_0's multi_logloss: 0.058633
# [266]	valid_0's multi_logloss: 0.0586348
# [267]	valid_0's multi_logloss: 0.0586366
# [268]	valid_0's multi_logloss: 0.0586385
# [269]	valid_0's multi_logloss: 0.0586403
# [270]	valid_0's multi_logloss: 0.0586421
# [271]	valid_0's multi_logloss: 0.0586439
# [272]	valid_0's multi_logloss: 0.0586456
# [273]	valid_0's multi_logloss: 0.0586474
# [274]	valid_0's multi_logloss: 0.0586492
# [275]	valid_0's multi_logloss: 0.058651
# [276]	valid_0's multi_logloss: 0.0586527
# [277]	valid_0's multi_logloss: 0.0586545
# [278]	valid_0's multi_logloss: 0.0586563
# [279]	valid_0's multi_logloss: 0.058658
# [280]	valid_0's multi_logloss: 0.0586597
# [281]	valid_0's multi_logloss: 0.0586615
# [282]	valid_0's multi_logloss: 0.0586632
# [283]	valid_0's multi_logloss: 0.0586649
# [284]	valid_0's multi_logloss: 0.0586666
# [285]	valid_0's multi_logloss: 0.0586683
# [286]	valid_0's multi_logloss: 0.05867
# [287]	valid_0's multi_logloss: 0.0586717
# [288]	valid_0's multi_logloss: 0.0586734
# [289]	valid_0's multi_logloss: 0.0586751
# [290]	valid_0's multi_logloss: 0.0586768
# [291]	valid_0's multi_logloss: 0.0586784
# [292]	valid_0's multi_logloss: 0.0586801
# [293]	valid_0's multi_logloss: 0.0586818
# [294]	valid_0's multi_logloss: 0.0586834
# [295]	valid_0's multi_logloss: 0.0586851
# [296]	valid_0's multi_logloss: 0.0586867
# [297]	valid_0's multi_logloss: 0.0586884
# [298]	valid_0's multi_logloss: 0.05869
# [299]	valid_0's multi_logloss: 0.0586916
# [300]	valid_0's multi_logloss: 0.0586932
# [301]	valid_0's multi_logloss: 0.0586949
# [302]	valid_0's multi_logloss: 0.0586965
# [303]	valid_0's multi_logloss: 0.0586981
# [304]	valid_0's multi_logloss: 0.0586997
# [305]	valid_0's multi_logloss: 0.0587013
# [306]	valid_0's multi_logloss: 0.0587029
# [307]	valid_0's multi_logloss: 0.0587044
# [308]	valid_0's multi_logloss: 0.058706
# [309]	valid_0's multi_logloss: 0.0587076
# [310]	valid_0's multi_logloss: 0.0587092
# [311]	valid_0's multi_logloss: 0.0587107
# [312]	valid_0's multi_logloss: 0.0587123
# [313]	valid_0's multi_logloss: 0.0587139
# [314]	valid_0's multi_logloss: 0.0587154
# [315]	valid_0's multi_logloss: 0.0587169
# [316]	valid_0's multi_logloss: 0.0587185
# [317]	valid_0's multi_logloss: 0.05872
# [318]	valid_0's multi_logloss: 0.0587215
# [319]	valid_0's multi_logloss: 0.0587231
# [320]	valid_0's multi_logloss: 0.0587246
# [321]	valid_0's multi_logloss: 0.0587261
# [322]	valid_0's multi_logloss: 0.0587276
# [323]	valid_0's multi_logloss: 0.0587291
# [324]	valid_0's multi_logloss: 0.0587306
# [325]	valid_0's multi_logloss: 0.0587321
# [326]	valid_0's multi_logloss: 0.0587336
# [327]	valid_0's multi_logloss: 0.0587351
# [328]	valid_0's multi_logloss: 0.0587366
# [329]	valid_0's multi_logloss: 0.058738
# [330]	valid_0's multi_logloss: 0.0587395
# [331]	valid_0's multi_logloss: 0.058741
# [332]	valid_0's multi_logloss: 0.0587425
# [333]	valid_0's multi_logloss: 0.0587439
# [334]	valid_0's multi_logloss: 0.0587454
# [335]	valid_0's multi_logloss: 0.0587468
# [336]	valid_0's multi_logloss: 0.0587483
# [337]	valid_0's multi_logloss: 0.0587497
# [338]	valid_0's multi_logloss: 0.0587511
# [339]	valid_0's multi_logloss: 0.0587526
# [340]	valid_0's multi_logloss: 0.058754
# [341]	valid_0's multi_logloss: 0.0587554
# [342]	valid_0's multi_logloss: 0.0587568
# [343]	valid_0's multi_logloss: 0.0587583
# [344]	valid_0's multi_logloss: 0.0587597
# [345]	valid_0's multi_logloss: 0.0587611
# [346]	valid_0's multi_logloss: 0.0587625
# [347]	valid_0's multi_logloss: 0.0587639
# [348]	valid_0's multi_logloss: 0.0587653
# [349]	valid_0's multi_logloss: 0.0587667
# [350]	valid_0's multi_logloss: 0.0587681
# [351]	valid_0's multi_logloss: 0.0587694
# [352]	valid_0's multi_logloss: 0.0587708
# [353]	valid_0's multi_logloss: 0.0587722
# [354]	valid_0's multi_logloss: 0.0587736
# [355]	valid_0's multi_logloss: 0.0587749
# [356]	valid_0's multi_logloss: 0.0587763
# [357]	valid_0's multi_logloss: 0.0587777
# [358]	valid_0's multi_logloss: 0.058779
# [359]	valid_0's multi_logloss: 0.0587804
# [360]	valid_0's multi_logloss: 0.0587817
# [361]	valid_0's multi_logloss: 0.0587831
# [362]	valid_0's multi_logloss: 0.0587844
# [363]	valid_0's multi_logloss: 0.0587858
# [364]	valid_0's multi_logloss: 0.0587871
# [365]	valid_0's multi_logloss: 0.0587884
# [366]	valid_0's multi_logloss: 0.0587897
# [367]	valid_0's multi_logloss: 0.0587911
# [368]	valid_0's multi_logloss: 0.0587924
# [369]	valid_0's multi_logloss: 0.0587937
# [370]	valid_0's multi_logloss: 0.058795
# [371]	valid_0's multi_logloss: 0.0587963
# [372]	valid_0's multi_logloss: 0.0587976
# [373]	valid_0's multi_logloss: 0.0587989
# [374]	valid_0's multi_logloss: 0.0588002
# [375]	valid_0's multi_logloss: 0.0588015
# [376]	valid_0's multi_logloss: 0.0588028
# [377]	valid_0's multi_logloss: 0.0588041
# [378]	valid_0's multi_logloss: 0.0588054
# [379]	valid_0's multi_logloss: 0.0588066
# [380]	valid_0's multi_logloss: 0.0588079
# [381]	valid_0's multi_logloss: 0.0588092
# [382]	valid_0's multi_logloss: 0.0588105
# [383]	valid_0's multi_logloss: 0.0588117
# [384]	valid_0's multi_logloss: 0.058813
# [385]	valid_0's multi_logloss: 0.0588143
# [386]	valid_0's multi_logloss: 0.0588155
# [387]	valid_0's multi_logloss: 0.0588168
# [388]	valid_0's multi_logloss: 0.058818
# [389]	valid_0's multi_logloss: 0.0588193
# [390]	valid_0's multi_logloss: 0.0588205
# [391]	valid_0's multi_logloss: 0.0588217
# [392]	valid_0's multi_logloss: 0.058823
# [393]	valid_0's multi_logloss: 0.0588242
# [394]	valid_0's multi_logloss: 0.0588254
# [395]	valid_0's multi_logloss: 0.0588267
# [396]	valid_0's multi_logloss: 0.0588279
# [397]	valid_0's multi_logloss: 0.0588291
# [398]	valid_0's multi_logloss: 0.0588303
# [399]	valid_0's multi_logloss: 0.0588316
# [400]	valid_0's multi_logloss: 0.0588328
# Did not meet early stopping. Best iteration is:
# [49]	valid_0's multi_logloss: 0.0561819

# %% [markdown]
# # 평가

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred, pos_label='positive', average='micro')
    recall = recall_score(y_test , pred, pos_label='positive', average='micro')
    f1 = f1_score(y_test,pred, average='micro')
    # ROC-AUC 추가 
#     roc_auc = roc_auc_score(y_test, pred_proba, average='micro' , multi_class = 'ovo')
    print('오차 행렬')
    print(confusion)
    
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    
#     # ROC-AUC print 추가
#     print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
#     F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
get_clf_eval(y_test, preds, pred_proba)
# Out:
# 오차 행렬
# [[2142    0    2]
#  [  26    0    1]
#  [   7    0   28]]
# 정확도: 0.9837, 정밀도: 0.9837, 재현율: 0.9837,    F1: 0.9837

# %%
# # plot_importance( )를 이용하여 feature 중요도 시각화
# from lightgbm import plot_importance
# import matplotlib.pyplot as plt
# %matplotlib inline

# fig, ax = plt.subplots(figsize=(10, 12))
# plot_importance(lgbm_wrapper, ax=ax)

# %%
df_test['preds'] = preds
df_test['pred_proba'] = pred_proba

df_test2 = df_test
del df_test2['X_features']
df_test2
# Out:
#       label          C1  preds  pred_proba
# 0         0      1원 스토어      0    0.001117
# 1         0  2048 파스포푸트      0    0.098851
# 2         0         app      0    0.012952
# 3         0   app store      0    0.000399
# 4         0   app store      0    0.000399
# ...     ...         ...    ...         ...
# 2201      0         한게임      0    0.005123
# 2202      0         한게임      0    0.005123
# 2203      0         한게임      0    0.005123
# 2204      0        헤이데이      0    0.098851
# 2205      0          황제      0    0.098851
#
# [2206 rows x 4 columns]

# %%
#엑셀 저장
df_test2.to_excel('google_result_20201213.xlsx',sheet_name='result')
