# %%
import pandas as pd

df= pd.read_excel('2019 google BAD sample(1-12).xlsx')
df.columns =['ID','label','C1']
df.head()
# Out:
#           ID  label       C1
# 0  201927622      1     test
# 1  201927623      1     qprm
# 2  201927624      1    qwert
# 3  201927625      1  fgfghfg
# 4  201927626      1     pubg

# %%
df
# Out:
#               ID  label       C1
# 0      201927622      1     test
# 1      201927623      1     qprm
# 2      201927624      1    qwert
# 3      201927625      1  fgfghfg
# 4      201927626      1     pubg
# ...          ...    ...      ...
# 27902  201927617      0       없음
# 27903  201927618      0      애니팡
# 27904  201927619      0     앱스토어
# 27905  201927620      0    애플스토어
# 27906  201927621      0   플레이스토아
#
# [27907 rows x 3 columns]

# %%
#fasttext에서 사용될 포맷으로 저장하려함
train = open('google_train','w',encoding='utf-8')

# %%
#fasttext 포맷으로 저장
#27854
for index,row in df.iterrows():
    #print(row["label"])
    print(f'__label__{row["label"]} {row["C1"]}', file=train)

# %% [markdown]
# # Fasttext

# %%
import fasttext
model = fasttext.train_supervised('google_train')
#model.save_model("google_train.bin")
#model = fasttext.load_model('google_train.bin')

# %%
print(model.labels)
# Out:
# ['__label__0', '__label__1']

# %%
print(model.words)
# Out:
# ['</s>', '플레이스토어', '구글', '구글플레이', '앱스토어', '스토어', '플레이', '구글스토어', '구글플레이스토어', '원스토어', 'play', 'play스토어', 'store', '애플', '애플스토어', '카카오', '구글플레이어', '구글앱스토어', '없음', 'app', '카카오게임', '애니팡', '리니지', '모름', '넥슨', '넷마블', 'Play', '애플앱스토어', 'App', 'google', '아이폰', '배틀그라운드', '스팀', '앱', 'Store', 'playstore', '모두의마블', '쿠키런', 'Play스토어', '아이튠즈', '구글앱', '플레이어', '안드로이드', '한게임', '네이버', '마블', 'Google', '사천성', '카카오톡', '피망', '플래이스토어', '구글play', '삼성', '플레이스토아', '모두의', '잘', 'ios', '없다', '게임', '기억안남', '검은사막', '맞고', 'PLAY', 'APP', '아이폰앱스토어', 'STORE', '컴투스', '구글플래이', 'PLAY스토어', '윈스토어', '캔디크러쉬', '모르겠음', '클래시로얄', 'appstore', '리니지m', '삼국지', '프렌즈팝', 'apple', '브롤스타즈', '롤', '엡스토어', '원', '배그', '마켓', '세븐나이츠', '카카오프렌즈', '카카오게임즈', '하스스톤', '피파', '구글마켓', '티스토어', '블리자드', '갤럭시스토어', '앱스토어,', '없습니다', '스토아', '모르겠다', '넥센', '메이플스토리', '신맞고', '플래이', '크레이지아케이드', '구글플레이,', '슈퍼셀', '카트라이더', '앵그리버드', 't스토어', '구글play스토어', '클래시오브클랜', '피파온라인', '플레이스터어', '녹스', '플레이스토', '생각안남', '플레어스토어', 'IOS', '몰라요', '서든어택', 'test', '모바일', '플레이스토어,', '베틀그라운드', '잘모름', '리니지2', '오리진', '클래시', 'steam', '프렌즈팝콘', '테트리스', '구굴', '구글플래이스토어', '갤럭시', '플레이구글', '리니지M', '프렌즈', 'one', '오브', '0', '어플스토어', '게임을', '고스톱', '원스토아', '게임빌', 'EA', '아스팔트', 'Appstore', 'rnrmf', '캔디팡', '
지막날', '플레이앱', '킹', '구글앱스토어,', '영웅', '일반', 'play구글', '쿠팡', 'NOX', '배틀', 'play앱스토어', '10000', '써든어택', '앵그리', '클래시오브로얄', '기적', '경험이', '플레이스토리', '해', 'sk스토어', '구글플레이게임', 'NC소프트', '게임즈', '와우', 'NBA', '고글', 'rpdla', '네이버게임', '경험없음', 'sotre', '레이스토어', '플레시스토어', '애플스토어,', '피망포커', '신명', 'Apple', '클래식로얄', '플레이마켓', '기억이안남', '파티게임즈', '원게임', '앱스토러', '(애플)', '모모', '검은', '구글플레이서비스', '구굴플레이어', 'iso', '???', 'r구글', '아타리', '장기', '그토어', 'for', '레볼루션', 'rpg', '타이니팜', 'ahfm', '트라하', '3', '유희왕', '듀얼링크스', '플레어', 'googlestore', '온', 'blast', '123', '구글스테이션', '섯다', 'cashbag', '구글풀레이어', '웹스토어', '갑자기', '안', '펜타스톰', '오캐이캐쉬백', 'm', '게임소프트', '달콤소프트', 'iTunes', '플헤이스토어', '퓨처파이트', '뭘', '스테이션', '블록퍼즐', '신맞고,', '안해서', 'supercell', '놀러와마이홈', '왕이', '서비스', '티월드', '유투브', '리니지엠', '모바일배그', '팡팡', '소니', '구글PLAY스토어', '플레이스토어.', 'doqtmxhdj', '카카오앱', '크래쉬로얄', 'plat스토어', '앱스토어(iOS)', '팜', '1', '트립', '앱플레이', '구굴스토어', 'king', '아이튠스', 'Play앱스토어', '윈 ...

# %%
#model.test("google_train", k=5)
model.test("google_train")
#모델 건수,정밀도,재현율
# Out:
# (27854, 0.9900911897752567, 0.9900911897752567)

# %%
model.predict("xx")
# Out:
# (('__label__0',), array([1.00000966]))

# %%
dfTest= pd.read_excel('2019 google BAD sample(1-12).xlsx')
dfTest.columns =['ID','label','C1']
dfTest['label_predict'] = ''
dfTest['acc'] = ''

dfTest.head()
# Out:
#           ID  label       C1 label_predict acc
# 0  201927622      1     test
# 1  201927623      1     qprm
# 2  201927624      1    qwert
# 3  201927625      1  fgfghfg
# 4  201927626      1     pubg

# %%
for index,row in dfTest.iterrows():
    predictArr = model.predict(str(row["C1"]))
    dfTest.at[index,"label_predict"] = int(predictArr[0][0].replace('__label__',''))
    dfTest.at[index,"acc"] = str(predictArr[1][0])

# %%
dfTest
# Out:
#               ID  label       C1 label_predict                 acc
# 0      201927622      1     test             1  0.8533728718757629
# 1      201927623      1     qprm             0  0.9226698279380798
# 2      201927624      1    qwert             0  0.9294856786727905
# 3      201927625      1  fgfghfg             0  0.9410125017166138
# 4      201927626      1     pubg             0  0.9782525897026062
# ...          ...    ...      ...           ...                 ...
# 27902  201927617      0       없음             0  0.9999101161956787
# 27903  201927618      0      애니팡             0  1.0000020265579224
# 27904  201927619      0     앱스토어             0  1.0000098943710327
# 27905  201927620      0    애플스토어             0  1.0000081062316895
# 27906  201927621      0   플레이스토아             0  0.9999299049377441
#
# [27907 rows x 5 columns]

# %%
dfTest.to_excel('google_result.xlsx',sheet_name='result')
with pd.ExcelWriter('google_result.xlsx', mode='a') as writer:
    df.to_excel(writer, sheet_name='source')
